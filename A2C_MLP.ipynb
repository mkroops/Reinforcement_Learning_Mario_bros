# %%
# !pip install gym_super_mario_bros==7.4.0 nes_py

# !pip install torch torchvision torchaudio

# !pip install stable-baselines3[extra]

# %load_ext tensorboard
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gym_super_mario_bros==7.4.0
#   Downloading gym_super_mario_bros-7.4.0-py3-none-any.whl (199 kB)
# Collecting nes_py
#   Downloading nes_py-8.2.1.tar.gz (77 kB)
# Collecting gym>=0.17.2
#   Downloading gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (1.21.5)
# Collecting pyglet<=1.5.21,>=1.4.0
#   Downloading pyglet-1.5.21-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: tqdm>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (4.64.0)
# Collecting gym-notices>=0.0.4
#   Downloading gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gym>=0.17.2->nes_py) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in c:\programdata\anaconda3\lib\site-packages (from gym>=0.17.2->nes_py) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata>=4.8.0->gym>=0.17.2->nes_py) (3.7.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.48.2->nes_py) (0.4.4)
# Building wheels for collected packages: nes-py, gym
#   Building wheel for nes-py (setup.py): started
#   Building wheel for nes-py (setup.py): finished with status 'done'
#   Created wheel for nes-py: filename=nes_py-8.2.1-cp39-cp39-win_amd64.whl size=45834 sha256=80b15fd4230133d38fc5d27c456a9bf33915fd325d5d3ebddfce8bd3938ad85f
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\c6\e1\4b\dbbd5d4a46ad80c0149d5671edb272c728c130e4d5750ca1d2
#   Building wheel for gym (PEP 517): started
#   Building wheel for gym (PEP 517): finished with status 'done'
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827647 sha256=876eedb29ff947bcec735d7da37efe52e6c8d6830cf27aabb8d8441f4d207559
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\af\2b\30\5e78b8b9599f2a2286a582b8da80594f654bf0e18d825a4405
# Successfully built nes-py gym
# Installing collected packages: gym-notices, pyglet, gym, nes-py, gym-super-mario-bros
# Successfully installed gym-0.26.2 gym-notices-0.0.8 gym-super-mario-bros-7.4.0 nes-py-8.2.1 pyglet-1.5.21
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in c:\programdata\anaconda3\lib\site-packages (1.12.1)
# Requirement already satisfied: torchvision in c:\programdata\anaconda3\lib\site-packages (0.13.1)
# Requirement already satisfied: torchaudio in c:\programdata\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: typing_extensions in c:\programdata\anaconda3\lib\site-packages (from torch) (4.1.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (2021.10.8)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-1.8.0-py3-none-any.whl (174 kB)
# Requirement already satisfied: torch>=1.11 in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.12.1)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.4.2)
# Collecting importlib-metadata~=4.13
#   Downloading importlib_metadata-4.13.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.21.5)
# Collecting gym==0.21
#   Downloading gym-0.21.0.tar.gz (1.5 MB)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
# Requirement already satisfied: rich in c:\users\computing\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (12.5.1)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (9.0.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.64.0)
# Collecting autorom[accept-rom-license]~=0.6.0
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.8.0)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\computing\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (2.10.1)
# Collecting ale-py==0.7.4
#   Downloading ale_py-0.7.4-cp39-cp39-win_amd64.whl (904 kB)
# Collecting importlib-resources
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.27.1)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (8.0.4)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\computing\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in c:\users\computing\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.33.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.19.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: grpcio>=1.24.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.42.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (61.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Requirement already satisfied: typing_extensions in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (4.1.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2021.3)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\programdata\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.11.2)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from rich->stable-baselines3[extra]) (0.9.1)
# Building wheels for collected packages: gym, AutoROM.accept-rom-license
#   Building wheel for gym (setup.py): started
#   Building wheel for gym (setup.py): finished with status 'done'
#   Created wheel for gym: filename=gym-0.21.0-py3-none-any.whl size=1616825 sha256=e90c9badcdd6f49df6bd9a96a217ff1d4632204284b53467471d95b2aa416c8c
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\b3\50\6c\0a82c1358b4da2dbd9c1bb17e0f89467db32812ab236dbf6d5
#   Building wheel for AutoROM.accept-rom-license (PEP 517): started
#   Building wheel for AutoROM.accept-rom-license (PEP 517): finished with status 'done'
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446679 sha256=32e3a6325941153a44637ceacb1b9088bdb7417c654e289f5be170ec69c0e2b9
#   Stored in directory: c:\users\computing\appdata\local\pip\cache\wheels\b1\1f\f7\2da07cf4f81ea264bdaf043028749d88fe0c2227134a22cf80
# Successfully built gym AutoROM.accept-rom-license
# Installing collected packages: importlib-resources, importlib-metadata, gym, AutoROM.accept-rom-license, autorom, stable-baselines3, opencv-python, ale-py
#   Attempting uninstall: gym
#     Found existing installation: gym 0.26.2
#     Uninstalling gym-0.26.2:
#       Successfully uninstalled gym-0.26.2
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.7.4 autorom-0.6.1 gym-0.21.0 importlib-metadata-4.13.0 importlib-resources-5.12.0 opencv-python-4.7.0.72 stable-baselines3-1.8.0

# %%
import gym_super_mario_bros

from nes_py.wrappers import JoypadSpace

from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

import os

from stable_baselines3 import PPO
from stable_baselines3 import DQN
from stable_baselines3 import A2C

from stable_baselines3.common.callbacks import BaseCallback

# %%
# Base environment setup
env = gym_super_mario_bros.make('SuperMarioBros2-v0')
# Simplify controls
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
    
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-ebf56864c0dd38e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ebf56864c0dd38e");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
model = A2C('MlpPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.001, n_steps=256, seed=10)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
import time

# %%
start_time = time.time()
model.learn(total_timesteps=1000000, callback=callback)
training_time = time.time() - start_time
# Out:
# Logging to ./logs/PPO_1
# ----------------------------
# | time/              |     |
# |    fps             | 28  |
# |    iterations      | 1   |
# |    time_elapsed    | 8   |
# |    total_timesteps | 256 |
# ----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 512         |
# | train/                  |             |
# |    approx_kl            | 0.052752715 |
# |    clip_fraction        | 0.491       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.89       |
# |    explained_variance   | -0.00534    |
# |    learning_rate        | 0.001       |
# |    loss                 | 12.3        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.0397      |
# |    value_loss           | 201         |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 56        |
# |    iterations           | 3         |
# |    time_elapsed         | 13        |
# |    total_timesteps      | 768       |
# | train/                  |           |
# |    approx_kl            | 1.1001619 |
# |    clip_fraction        | 0.715     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.56     |
# |    explained_variance   | -0.335    |
# |    learning_rate        | 0.001     |
# |    loss                 | 30.4      |
# |    n_updates            | 20        |
# |    policy_gradient_loss | 0.172     |
# |    value_loss           | 141       |
# ---------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 65        |
# |    iterations           | 4         |
# |    time_elapsed         | 15        |
# |    total_timesteps      | 1024      |
# | train/                  |           |
# |    approx_kl            | 2.2536716 |
# |    clip_fraction        | 0.806     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.788    |
# |    explained_variance   | -0.856    |
# |    learning_rate        | 0.001     |
# |    loss                 | 5.48      |
# |    n_updates            | 30        |
# |    policy_gradient_loss | 0.129     |
# |    value_loss           | 10.7      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 72          |
# |    iterations           | 5           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.018139742 |
# |    clip_fraction        | 0.00742     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0202     |
# |    explained_variance   | -0.238      |
# |    learning_rate        | 0.001       |
# |    loss                 | 2.97        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.0111      |
# |    value_loss           | 6.86        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 78          |
# |    iterations           | 6           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.008000218 |
# |    clip_fraction        | 0.00391     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0598     |
# |    explained_variance   | 0.0198      |
# |    learning_rate        | 0.001       |
# |    loss                 | 1.36        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.000419   |
# |    value_loss           | 3.13        |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 82            |
# |    iterations           | 7             |
# |    time_elapsed         | 21            |
# |    total_timesteps      | 1792          |
# | train/                  |               |
# |    approx_kl            | 0.00063218595 |
# |    clip_fraction        | 0.00352       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.131        |
# |    explained_variance   | -0.0298       |
# |    learning_rate        | 0.001         |
# |    loss                 | 0.262         |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -0.000286     |
# |    value_loss           | 3.13          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 8           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.009363179 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.172      |
# |    explained_variance   | -0.213      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.797       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00643     |
# |    value_loss           | 1.3         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 88           |
# |    iterations           | 9            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 2304         |
# | train/                  |              |
# |    approx_kl            | 0.0026237993 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | -0.16        |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.26         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.00204      |
# |    value_loss           | 0.786        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 89           |
# |    iterations           | 10           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0032818993 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.355       |
# |    explained_variance   | -0.0148      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0663       |
# |    n_updates            | 90           |
# |    policy_gradient_loss | 0.0065       |
# |    value_loss           | 0.623        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 89         |
# |    iterations           | 11         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 2816       |
# | train/                  |            |
# |    approx_kl            | 0.09819257 |
# |    clip_fraction        | 0.0602     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.147     |
# |    explained_variance   | -0.153     |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0149     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | 0.00998    |
# |    value_loss           | 0.268      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 12          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.065911144 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.498      |
# |    explained_variance   | -0.0378     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0391      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00395    |
# |    value_loss           | 0.333       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 88           |
# |    iterations           | 13           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 0.0155687025 |
# |    clip_fraction        | 0.191        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.612       |
# |    explained_variance   | -0.108       |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0156       |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 0.0129       |
# |    value_loss           | 0.178        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 14          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.018324865 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.679      |
# |    explained_variance   | -0.0167     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.000325    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | 0.0125      |
# |    value_loss           | 0.157       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 15          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.050058402 |
# |    clip_fraction        | 0.332       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.392      |
# |    explained_variance   | 0.0727      |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0548      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.0439      |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 16          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.033791304 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00354     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0059     |
# |    value_loss           | 0.121       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 87          |
# |    iterations           | 17          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.042752475 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.329      |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.024       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00314    |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 18          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.011309408 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.247       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0347      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00222     |
# |    value_loss           | 0.138       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 19          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 4864        |
# | train/                  |             |
# |    approx_kl            | 0.017895982 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | 0.329       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.012       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00522    |
# |    value_loss           | 0.0857      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 86         |
# |    iterations           | 20         |
# |    time_elapsed         | 59         |
# |    total_timesteps      | 5120       |
# | train/                  |            |
# |    approx_kl            | 0.07369785 |
# |    clip_fraction        | 0.257      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.902     |
# |    explained_variance   | -0.128     |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0481     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.023     |
# |    value_loss           | 0.0926     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 21          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 5376        |
# | train/                  |             |
# |    approx_kl            | 0.026468158 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0161      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 0.0715      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 86          |
# |    iterations           | 22          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 5632        |
# | train/                  |             |
# |    approx_kl            | 0.016921474 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0118      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0205     |
# |    value_loss           | 0.0767      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 23          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 5888        |
# | train/                  |             |
# |    approx_kl            | 0.021498885 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.217       |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00269     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 0.074       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 24          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.024056206 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00897    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 0.0712      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 84         |
# |    iterations           | 25         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 6400       |
# | train/                  |            |
# |    approx_kl            | 0.02086291 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.313      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.000892   |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0208    |
# |    value_loss           | 0.0681     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 77         |
# |    iterations           | 26         |
# |    time_elapsed         | 85         |
# |    total_timesteps      | 6656       |
# | train/                  |            |
# |    approx_kl            | 0.03708621 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.317      |
# |    learning_rate        | 0.001      |
# |    loss                 | -0.0118    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0265    |
# |    value_loss           | 0.062      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 27         |
# |    time_elapsed         | 99         |
# |    total_timesteps      | 6912       |
# | train/                  |            |
# |    approx_kl            | 0.02655014 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.19      |
# |    explained_variance   | 0.198      |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.000918   |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0315    |
# |    value_loss           | 0.0665     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 28         |
# |    time_elapsed         | 110        |
# |    total_timesteps      | 7168       |
# | train/                  |            |
# |    approx_kl            | 0.02271498 |
# |    clip_fraction        | 0.271      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.985     |
# |    explained_variance   | 0.19       |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0162     |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0213    |
# |    value_loss           | 0.0931     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 29          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 7424        |
# | train/                  |             |
# |    approx_kl            | 0.035596415 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.0263     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00105    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0322     |
# |    value_loss           | 0.0806      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 56          |
# |    iterations           | 30          |
# |    time_elapsed         | 135         |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.036126934 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.938      |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0108     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 0.0698      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 52         |
# |    iterations           | 31         |
# |    time_elapsed         | 150        |
# |    total_timesteps      | 7936       |
# | train/                  |            |
# |    approx_kl            | 0.05203979 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.952     |
# |    explained_variance   | -0.0904    |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0207     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.027     |
# |    value_loss           | 0.0864     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 50          |
# |    iterations           | 32          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.037264798 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.0497     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0129     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0346     |
# |    value_loss           | 0.0797      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 49          |
# |    iterations           | 33          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 8448        |
# | train/                  |             |
# |    approx_kl            | 0.026388383 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.123      |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0248     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 0.0727      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 47          |
# |    iterations           | 34          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 8704        |
# | train/                  |             |
# |    approx_kl            | 0.034272365 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.0551      |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0366     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.13        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 35          |
# |    time_elapsed         | 199         |
# |    total_timesteps      | 8960        |
# | train/                  |             |
# |    approx_kl            | 0.027120464 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.00249    |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0127      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0315     |
# |    value_loss           | 0.17        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 36          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.055565402 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00359    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0411     |
# |    value_loss           | 0.157       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 37          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 9472        |
# | train/                  |             |
# |    approx_kl            | 0.051322725 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | -0.0394     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.0223     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0397     |
# |    value_loss           | 0.174       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 40         |
# |    iterations           | 38         |
# |    time_elapsed         | 242        |
# |    total_timesteps      | 9728       |
# | train/                  |            |
# |    approx_kl            | 0.04297063 |
# |    clip_fraction        | 0.383      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.33      |
# |    explained_variance   | -0.0193    |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0495     |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0506    |
# |    value_loss           | 0.177      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.87e+03    |
# |    ep_rew_mean          | 355         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 39          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 9984        |
# | train/                  |             |
# |    approx_kl            | 0.038712695 |
# |    clip_fraction        | 0.299       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.00371     |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.019      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0445     |
# |    value_loss           | 0.173       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 9.87e+03  |
# |    ep_rew_mean          | 355       |
# | time/                   |           |
# |    fps                  | 37        |
# |    iterations           | 40        |
# |    time_elapsed         | 271       |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 23.260725 |
# |    clip_fraction        | 0.89      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.287    |
# |    explained_variance   | 0.0932    |
# |    learning_rate        | 0.001     |
# |    loss                 | 18.2      |
# |    n_updates            | 390       |
# |    policy_gradient_loss | 0.337     |
# |    value_loss           | 295       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 9.87e+03  |
# |    ep_rew_mean          | 355       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 41        |
# |    time_elapsed         | 284       |
# |    total_timesteps      | 10496     |
# | train/                  |           |
# |    approx_kl            | 2.0904977 |
# |    clip_fraction        | 0.0414    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00308  |
# |    explained_variance   | 0.118     |
# |    learning_rate        | 0.001     |
# |    loss                 | 16.4      |
# |    n_updates            | 400       |
# |    policy_gradient_loss | 0.0117    |
# |    value_loss           | 245       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.28e+03  |
# |    ep_rew_mean          | 838       |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 42        |
# |    time_elapsed         | 298       |
# |    total_timesteps      | 10752     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.7e-17  |
# |    explained_variance   | 0.19      |
# |    learning_rate        | 0.001     |
# |    loss                 | 32.8      |
# |    n_updates            | 410       |
# |    policy_gradient_loss | -1.44e-08 |
# |    value_loss           | 368       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.28e+03    |
# |    ep_rew_mean          | 838         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 43          |
# |    time_elapsed         | 311         |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.008148052 |
# |    clip_fraction        | 0.00781     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0133     |
# |    explained_variance   | 0.388       |
# |    learning_rate        | 0.001       |
# |    loss                 | 12.4        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00613    |
# |    value_loss           | 182         |
# -----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 5.28e+03 |
# |    ep_rew_mean          | 838      |
# | time/                   |          |
# |    fps                  | 35       |
# |    iterations           | 44       |
# |    time_elapsed         | 319      |
# |    total_timesteps      | 11264    |
# | train/                  |          |
# |    approx_kl            | 1.875018 |
# |    clip_fraction        | 0.0332   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00362 |
# |    explained_variance   | -3.1     |
# |    learning_rate        | 0.001    |
# |    loss                 | 3.64     |
# |    n_updates            | 430      |
# |    policy_gradient_loss | 0.0272   |
# |    value_loss           | 96.1     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.28e+03  |
# |    ep_rew_mean          | 838       |
# | time/                   |           |
# |    fps                  | 34        |
# |    iterations           | 45        |
# |    time_elapsed         | 330       |
# |    total_timesteps      | 11520     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.8e-16  |
# |    explained_variance   | -0.277    |
# |    learning_rate        | 0.001     |
# |    loss                 | 2.41      |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -5.57e-08 |
# |    value_loss           | 27.9      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.28e+03  |
# |    ep_rew_mean          | 838       |
# | time/                   |           |
# |    fps                  | 34        |
# |    iterations           | 46        |
# |    time_elapsed         | 345       |
# |    total_timesteps      | 11776     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.62e-14 |
# |    explained_variance   | -0.188    |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.439     |
# |    n_updates            | 450       |
# |    policy_gradient_loss | 1.93e-08  |
# |    value_loss           | 2.54      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.28e+03  |
# |    ep_rew_mean          | 838       |
# | time/                   |           |
# |    fps                  | 33        |
# |    iterations           | 47        |
# |    time_elapsed         | 359       |
# |    total_timesteps      | 12032     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.33e-13 |
# |    explained_variance   | -0.101    |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.0991    |
# |    n_updates            | 460       |
# |    policy_gradient_loss | 3.41e-08  |
# |    value_loss           | 1.41      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.28e+03  |
# |    ep_rew_mean          | 838       |
# | time/                   |           |
# |    fps                  | 32        |
# |    iterations           | 48        |
# |    time_elapsed         | 372       |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.42e-08 |
# |    explained_variance   | -0.166    |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.666     |
# |    n_updates            | 470       |
# |    policy_gradient_loss | 6.66e-09  |
# |    value_loss           | 3.3       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.28e+03  |
# |    ep_rew_mean          | 838       |
# | time/                   |           |
# |    fps                  | 32        |
# |    iterations           | 49        |
# |    time_elapsed         | 387       |
# |    total_timesteps      | 12544     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.79e-08 |
# |    explained_variance   | -0.318    |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.21      |
# |    n_updates            | 480       |
# |    policy_gradient_loss | 1.76e-08  |
# |    value_loss           | 1.73      |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 5.28e+03  |
# |    ep_rew_mean          | 838       |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 50        |
# |    time_elapsed         | 402       |
# |    total_timesteps      | 12800     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.14e-06 |
# |    explained_variance   | -0.118    |
# |    learning_rate        | 0.001     |
# |    loss                 | 0.122     |
# |    n_updates            | 490       |
# |    policy_gradient_loss | -1.04e-08 |
# |    value_loss           | 0.693     |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5.28e+03      |
# |    ep_rew_mean          | 838           |
# | time/                   |               |
# |    fps                  | 31            |
# |    iterations           | 51            |
# |    time_elapsed         | 417           |
# |    total_timesteps      | 13056         |
# | train/                  |               |
# |    approx_kl            | 1.6530976e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000188     |
# |    explained_variance   | -0.354        |
# |    learning_rate        | 0.001         |
# |    loss                 | 0.0793        |
# |    n_updates            | 500           |
# |    policy_gradient_loss | 1.61e-06      |
# |    value_loss           | 0.466         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5.28e+03      |
# |    ep_rew_mean          | 838           |
# | time/                   |               |
# |    fps                  | 30            |
# |    iterations           | 52            |
# |    time_elapsed         | 432           |
# |    total_timesteps      | 13312         |
# | train/                  |               |
# |    approx_kl            | 2.6077032e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00222      |
# |    explained_variance   | -0.554        |
# |    learning_rate        | 0.001         |
# |    loss                 | 0.0863        |
# |    n_updates            | 510           |
# |    policy_gradient_loss | 5.63e-05      |
# |    value_loss           | 0.468         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 5.28e+03      |
# |    ep_rew_mean          | 838           |
# | time/                   |               |
# |    fps                  | 30            |
# |    iterations           | 53            |
# |    time_elapsed         | 446           |
# |    total_timesteps      | 13568         |
# | train/                  |               |
# |    approx_kl            | 3.5802368e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0177       |
# |    explained_variance   | -0.0242       |
# |    learning_rate        | 0.001         |
# |    loss                 | 0.067         |
# |    n_updates            | 520           |
# |    policy_gradient_loss | -1.42e-05     |
# |    value_loss           | 0.391         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 5.28e+03     |
# |    ep_rew_mean          | 838          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 54           |
# |    time_elapsed         | 459          |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 0.0059414133 |
# |    clip_fraction        | 0.00391      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | -0.0159      |
# |    learning_rate        | 0.001        |
# |    loss                 | 0.0662       |
# |    n_updates            | 530          |
# |    policy_gradient_loss | 0.000688     |
# |    value_loss           | 0.239        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.28e+03    |
# |    ep_rew_mean          | 838         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 55          |
# |    time_elapsed         | 468         |
# |    total_timesteps      | 14080       |
# | train/                  |             |
# |    approx_kl            | 0.006497085 |
# |    clip_fraction        | 0.00391     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.025      |
# |    explained_variance   | -0.0705     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0503      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | 0.00281     |
# |    value_loss           | 0.221       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.28e+03    |
# |    ep_rew_mean          | 838         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 56          |
# |    time_elapsed         | 483         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010437658 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.287      |
# |    explained_variance   | -0.0358     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0454      |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 0.226       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.28e+03    |
# |    ep_rew_mean          | 838         |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 57          |
# |    time_elapsed         | 497         |
# |    total_timesteps      | 14592       |
# | train/                  |             |
# |    approx_kl            | 0.020851871 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.578      |
# |    explained_variance   | -0.00791    |
# |    learning_rate        | 0.001       |
# |    loss                 | -0.00399    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.00336     |
# |    value_loss           | 0.162       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 5.28e+03   |
# |    ep_rew_mean          | 838        |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 58         |
# |    time_elapsed         | 511        |
# |    total_timesteps      | 14848      |
# | train/                  |            |
# |    approx_kl            | 0.04989802 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.8       |
# |    explained_variance   | -0.0357    |
# |    learning_rate        | 0.001      |
# |    loss                 | 0.0661     |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.0179    |
# |    value_loss           | 0.149      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.28e+03    |
# |    ep_rew_mean          | 838         |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 59          |
# |    time_elapsed         | 525         |
# |    total_timesteps      | 15104       |
# | train/                  |             |
# |    approx_kl            | 0.033598356 |
# |    clip_fraction        | 0.0793      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.456      |
# |    explained_variance   | -0.0511     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.00873     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00634    |
# |    value_loss           | 0.132       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.28e+03    |
# |    ep_rew_mean          | 838         |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 60          |
# |    time_elapsed         | 539         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.034457594 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.509      |
# |    explained_variance   | 0.00682     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0284      |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00291    |
# |    value_loss           | 0.105       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.28e+03    |
# |    ep_rew_mean          | 838         |
# | time/                   |             |
# |    fps                  | 28          |
# |    iterations           | 61          |
# |    time_elapsed         | 552         |
# |    total_timesteps      | 15616       |
# | train/                  |             |
# |    approx_kl            | 0.022396047 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | -0.0651     |
# |    learning_rate        | 0.001       |
# |    loss                 | 0.0772      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00736    |
# ...
# |    loss                 | 82.1     |
# |    n_updates            | 8530     |
# |    policy_gradient_loss | 1.35e-09 |
# |    value_loss           | 165      |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 637        |
# |    ep_rew_mean          | 1.32e+03   |
# | time/                   |            |
# |    fps                  | 19         |
# |    iterations           | 855        |
# |    time_elapsed         | 11346      |
# |    total_timesteps      | 218880     |
# | train/                  |            |
# |    approx_kl            | 0.26771906 |
# |    clip_fraction        | 0.00273    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2e-15   |
# |    explained_variance   | 0.643      |
# |    learning_rate        | 0.001      |
# |    loss                 | 129        |
# |    n_updates            | 8540       |
# |    policy_gradient_loss | -0.00198   |
# |    value_loss           | 409        |
# ----------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 637      |
# |    ep_rew_mean          | 1.32e+03 |
# | time/                   |          |
# |    fps                  | 19       |
# |    iterations           | 856      |
# |    time_elapsed         | 11360    |
# |    total_timesteps      | 219136   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0        |
# |    explained_variance   | 0.628    |
# |    learning_rate        | 0.001    |
# |    loss                 | 63.6     |
# |    n_updates            | 8550     |
# |    policy_gradient_loss | 3.05e-09 |
# |    value_loss           | 196      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 637       |
# |    ep_rew_mean          | 1.32e+03  |
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 857       |
# |    time_elapsed         | 11374     |
# |    total_timesteps      | 219392    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -6.67e-16 |
# |    explained_variance   | 0.75      |
# |    learning_rate        | 0.001     |
# |    loss                 | 39.8      |
# |    n_updates            | 8560      |
# |    policy_gradient_loss | -1.28e-09 |
# |    value_loss           | 291       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 637      |
# |    ep_rew_mean          | 1.32e+03 |
# | time/                   |          |
# |    fps                  | 19       |
# |    iterations           | 858      |
# |    time_elapsed         | 11388    |
# |    total_timesteps      | 219648   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0        |
# |    explained_variance   | 0.508    |
# |    learning_rate        | 0.001    |
# |    loss                 | 13       |
# |    n_updates            | 8570     |
# |    policy_gradient_loss | 9.31e-10 |
# |    value_loss           | 70.7     |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 637       |
# |    ep_rew_mean          | 1.32e+03  |
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 859       |
# |    time_elapsed         | 11402     |
# |    total_timesteps      | 219904    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0         |
# |    explained_variance   | 0.71      |
# |    learning_rate        | 0.001     |
# |    loss                 | 74.3      |
# |    n_updates            | 8580      |
# |    policy_gradient_loss | -1.37e-09 |
# |    value_loss           | 202       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 637       |
# |    ep_rew_mean          | 1.32e+03  |
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 860       |
# |    time_elapsed         | 11418     |
# |    total_timesteps      | 220160    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -7.75e-17 |
# |    explained_variance   | 0.769     |
# |    learning_rate        | 0.001     |
# |    loss                 | 124       |
# |    n_updates            | 8590      |
# |    policy_gradient_loss | 2.7e-09   |
# |    value_loss           | 462       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 637       |
# |    ep_rew_mean          | 1.32e+03  |
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 861       |
# |    time_elapsed         | 11432     |
# |    total_timesteps      | 220416    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0         |
# |    explained_variance   | 0.739     |
# |    learning_rate        | 0.001     |
# |    loss                 | 86.5      |
# |    n_updates            | 8600      |
# |    policy_gradient_loss | -5.36e-09 |
# |    value_loss           | 215       |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 637       |
# |    ep_rew_mean          | 1.32e+03  |
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 862       |
# |    time_elapsed         | 11446     |
# |    total_timesteps      | 220672    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.23e-16 |
# |    explained_variance   | 0.839     |
# |    learning_rate        | 0.001     |
# |    loss                 | 357       |
# |    n_updates            | 8610      |
# |    policy_gradient_loss | 1.72e-09  |
# |    value_loss           | 474       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 637      |
# |    ep_rew_mean          | 1.32e+03 |
# | time/                   |          |
# |    fps                  | 19       |
# |    iterations           | 863      |
# |    time_elapsed         | 11461    |
# |    total_timesteps      | 220928   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0        |
# |    explained_variance   | 0.813    |
# |    learning_rate        | 0.001    |
# |    loss                 | 30.5     |
# |    n_updates            | 8620     |
# |    policy_gradient_loss | 4.89e-09 |
# |    value_loss           | 56.6     |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 637      |
# |    ep_rew_mean          | 1.32e+03 |
# | time/                   |          |
# |    fps                  | 19       |
# |    iterations           | 864      |
# |    time_elapsed         | 11475    |
# |    total_timesteps      | 221184   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0        |
# |    explained_variance   | 0.763    |
# |    learning_rate        | 0.001    |
# |    loss                 | 89       |
# |    n_updates            | 8630     |
# |    policy_gradient_loss | -2e-09   |
# |    value_loss           | 216      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 637       |
# |    ep_rew_mean          | 1.32e+03  |
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 865       |
# |    time_elapsed         | 11490     |
# |    total_timesteps      | 221440    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.17e-17 |
# |    explained_variance   | 0.754     |
# |    learning_rate        | 0.001     |
# |    loss                 | 172       |
# |    n_updates            | 8640      |
# |    policy_gradient_loss | -1.33e-09 |
# |    value_loss           | 455       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 637      |
# |    ep_rew_mean          | 1.32e+03 |
# | time/                   |          |
# |    fps                  | 19       |
# |    iterations           | 866      |
# |    time_elapsed         | 11501    |
# |    total_timesteps      | 221696   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0        |
# |    explained_variance   | 0.733    |
# |    learning_rate        | 0.001    |
# |    loss                 | 141      |
# |    n_updates            | 8650     |
# |    policy_gradient_loss | 8.15e-10 |
# |    value_loss           | 193      |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 637      |
# |    ep_rew_mean          | 1.32e+03 |
# | time/                   |          |
# |    fps                  | 19       |
# |    iterations           | 867      |
# |    time_elapsed         | 11512    |
# |    total_timesteps      | 221952   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -1.5e-15 |
# |    explained_variance   | 0.829    |
# |    learning_rate        | 0.001    |
# |    loss                 | 276      |
# |    n_updates            | 8660     |
# |    policy_gradient_loss | 2.05e-09 |
# |    value_loss           | 509      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 637       |
# |    ep_rew_mean          | 1.32e+03  |
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 868       |
# |    time_elapsed         | 11522     |
# |    total_timesteps      | 222208    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 0         |
# |    explained_variance   | 0.789     |
# |    learning_rate        | 0.001     |
# |    loss                 | 29.3      |
# |    n_updates            | 8670      |
# |    policy_gradient_loss | -3.49e-10 |
# |    value_loss           | 64.1      |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 637      |
# |    ep_rew_mean          | 1.32e+03 |
# | time/                   |          |
# |    fps                  | 19       |
# |    iterations           | 869      |
# |    time_elapsed         | 11535    |
# |    total_timesteps      | 222464   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0        |
# |    explained_variance   | 0.797    |
# |    learning_rate        | 0.001    |
# |    loss                 | 67.9     |
# |    n_updates            | 8680     |
# |    policy_gradient_loss | 3.26e-10 |
# |    value_loss           | 196      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 637       |
# |    ep_rew_mean          | 1.32e+03  |
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 870       |
# |    time_elapsed         | 11550     |
# |    total_timesteps      | 222720    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -9.86e-17 |
# |    explained_variance   | 0.716     |
# |    learning_rate        | 0.001     |
# |    loss                 | 126       |
# |    n_updates            | 8690      |
# |    policy_gradient_loss | 2.61e-09  |
# |    value_loss           | 362       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 637      |
# |    ep_rew_mean          | 1.32e+03 |
# | time/                   |          |
# |    fps                  | 19       |
# |    iterations           | 871      |
# |    time_elapsed         | 11565    |
# |    total_timesteps      | 222976   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0        |
# |    explained_variance   | 0.747    |
# |    learning_rate        | 0.001    |
# |    loss                 | 20       |
# |    n_updates            | 8700     |
# |    policy_gradient_loss | 1.01e-08 |
# |    value_loss           | 141      |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 637       |
# |    ep_rew_mean          | 1.32e+03  |
# | time/                   |           |
# |    fps                  | 19        |
# |    iterations           | 872       |
# |    time_elapsed         | 11579     |
# |    total_timesteps      | 223232    |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.38e-12 |
# |    explained_variance   | 0.777     |
# |    learning_rate        | 0.001     |
# |    loss                 | 124       |
# |    n_updates            | 8710      |
# |    policy_gradient_loss | -2.47e-09 |
# |    value_loss           | 470       |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 637      |
# |    ep_rew_mean          | 1.32e+03 |
# | time/                   |          |
# |    fps                  | 19       |
# |    iterations           | 873      |
# |    time_elapsed         | 11593    |
# |    total_timesteps      | 223488   |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 0        |
# |    explained_variance   | 0.861    |
# |    learning_rate        | 0.001    |
# |    loss                 | 41       |
# |    n_updates            | 8720     |
# |    policy_gradient_loss | 1.42e-09 |
# |    value_loss           | 48.3     |
# --------------------------------------

# %%
import numpy as np
import tensorflow as tf

# %%
obs = env.reset()
start_time = time.time()
total_rewards = 0
game_scores = []
steps_per_episode = []
episode_rewards = []
while True:
    action, states = model.predict(obs.copy())
    action = action.item()  # convert NumPy array to scalar integer
    obs, rewards, done, info = env.step((action))
    total_rewards += rewards
    episode_rewards.append(rewards)
    if done:
        game_scores.append(info['score'])
        steps_per_episode.append(len(episode_rewards))
        episode_rewards = []
        obs = env.reset()
        if len(game_scores) == 10:
            break
test_time = time.time() - start_time

# %%
print(f'Average steps per episode for seed 10: {sum(steps_per_episode)/len(steps_per_episode)}')
print(f'Average mean reward for seed 10: {total_rewards/len(game_scores)}')
print(f'Average game score for seed 10: {sum(game_scores)/len(game_scores)}')
print(f'Training time for seed 10: {training_time:.2f} seconds')
print(f'Test time for seed 10: {test_time:.2f} seconds')

# %%
model = A2C.load('./train/best_model_1000000/')
