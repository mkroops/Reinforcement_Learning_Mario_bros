# %%
# !pip install gym_super_mario_bros==7.4.0 nes_py

# !pip install torch torchvision torchaudio

# !pip install stable-baselines3[extra]

# %load_ext tensorboard
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gym_super_mario_bros==7.4.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (7.4.0)
# Requirement already satisfied: nes_py in c:\users\computing\appdata\roaming\python\python39\site-packages (8.2.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (1.21.5)
# Requirement already satisfied: tqdm>=4.48.2 in c:\programdata\anaconda3\lib\site-packages (from nes_py) (4.64.0)
# Requirement already satisfied: gym>=0.17.2 in c:\users\computing\appdata\roaming\python\python39\site-packages (from nes_py) (0.21.0)
# Requirement already satisfied: pyglet<=1.5.21,>=1.4.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from nes_py) (1.5.21)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gym>=0.17.2->nes_py) (2.0.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.48.2->nes_py) (0.4.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in c:\programdata\anaconda3\lib\site-packages (1.12.1)
# Requirement already satisfied: torchvision in c:\programdata\anaconda3\lib\site-packages (0.13.1)
# Requirement already satisfied: torchaudio in c:\programdata\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: typing_extensions in c:\programdata\anaconda3\lib\site-packages (from torch) (4.1.1)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (2021.10.8)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3[extra] in c:\users\computing\appdata\roaming\python\python39\site-packages (1.8.0)
# Requirement already satisfied: torch>=1.11 in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.12.1)
# Requirement already satisfied: importlib-metadata~=4.13 in c:\users\computing\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.21.5)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: cloudpickle in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: gym==0.21 in c:\users\computing\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: tensorboard>=2.9.1 in c:\users\computing\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (2.10.1)
# Requirement already satisfied: opencv-python in c:\users\computing\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (4.7.0.72)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: rich in c:\users\computing\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (12.5.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (4.64.0)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (5.8.0)
# Requirement already satisfied: pillow in c:\programdata\anaconda3\lib\site-packages (from stable-baselines3[extra]) (9.0.1)
# Requirement already satisfied: ale-py==0.7.4 in c:\users\computing\appdata\roaming\python\python39\site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: importlib-resources in c:\users\computing\appdata\roaming\python\python39\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.12.0)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.27.1)
# Requirement already satisfied: AutoROM.accept-rom-license in c:\users\computing\appdata\roaming\python\python39\site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in c:\users\computing\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\computing\appdata\roaming\python\python39\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (61.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.19.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.33.0)
# Requirement already satisfied: grpcio>=1.24.3 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.42.0)
# Requirement already satisfied: wheel>=0.26 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\programdata\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\programdata\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Requirement already satisfied: typing_extensions in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11->stable-baselines3[extra]) (4.1.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas->stable-baselines3[extra]) (2021.3)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\computing\appdata\roaming\python\python39\site-packages (from rich->stable-baselines3[extra]) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\programdata\anaconda3\lib\site-packages (from rich->stable-baselines3[extra]) (2.11.2)

# %%
import gym_super_mario_bros

from nes_py.wrappers import JoypadSpace

from gym_super_mario_bros.actions import SIMPLE_MOVEMENT

import os

from stable_baselines3 import PPO
from stable_baselines3 import DQN
from stable_baselines3 import A2C

from stable_baselines3.common.callbacks import BaseCallback

# %%
# Base environment setup
env = gym_super_mario_bros.make('SuperMarioBros2-v0')
# Simplify controls
env = JoypadSpace(env, SIMPLE_MOVEMENT)

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
    
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/'
LOG_DIR = './logs/'

# %%
# %tensorboard --logdir logs
# Out:
# Reusing TensorBoard on port 6006 (pid 11692), started 0:05:00 ago. (Use '!kill 11692' to kill it.)
#       <iframe id="tensorboard-frame-69d5739bd1f21f33" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-69d5739bd1f21f33");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %%
model = DQN('CnnPolicy', env, verbose=1, tensorboard_log=LOG_DIR, learning_rate=0.001, buffer_size=256, seed=20)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
import time

# %%
start_time = time.time()
model.learn(total_timesteps=1000000, callback=callback)
training_time = time.time() - start_time
# Out:
# Logging to ./logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.71e+04 |
# |    ep_rew_mean      | 554      |
# |    exploration_rate | 0.351    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 188      |
# |    time_elapsed     | 363      |
# |    total_timesteps  | 68334    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0318   |
# |    n_updates        | 4583     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.2e+04  |
# |    ep_rew_mean      | 1.05e+03 |
# |    exploration_rate | 0.0857   |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 119      |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 96239    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0309   |
# |    n_updates        | 11559    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 8.44e+03 |
# |    ep_rew_mean      | 984      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 113      |
# |    time_elapsed     | 889      |
# |    total_timesteps  | 101265   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.138    |
# |    n_updates        | 12816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.71e+03 |
# |    ep_rew_mean      | 1.06e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 108      |
# |    time_elapsed     | 986      |
# |    total_timesteps  | 107310   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.235    |
# |    n_updates        | 14327    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 6.09e+03 |
# |    ep_rew_mean      | 1.23e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 99       |
# |    time_elapsed     | 1222     |
# |    total_timesteps  | 121740   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.146    |
# |    n_updates        | 17934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.4e+03  |
# |    ep_rew_mean      | 1.24e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 95       |
# |    time_elapsed     | 1350     |
# |    total_timesteps  | 129641   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.56     |
# |    n_updates        | 19910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 5.14e+03 |
# |    ep_rew_mean      | 1.3e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 90       |
# |    time_elapsed     | 1580     |
# |    total_timesteps  | 143780   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.2      |
# |    n_updates        | 23444    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.85e+03 |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 87       |
# |    time_elapsed     | 1765     |
# |    total_timesteps  | 155142   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.182    |
# |    n_updates        | 26285    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.46e+03 |
# |    ep_rew_mean      | 1.34e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 86       |
# |    time_elapsed     | 1857     |
# |    total_timesteps  | 160710   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.281    |
# |    n_updates        | 27677    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.25e+03 |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 84       |
# |    time_elapsed     | 2006     |
# |    total_timesteps  | 169970   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.203    |
# |    n_updates        | 29992    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 4.06e+03 |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 83       |
# |    time_elapsed     | 2147     |
# |    total_timesteps  | 178643   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.932    |
# |    n_updates        | 32160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 81       |
# |    time_elapsed     | 2321     |
# |    total_timesteps  | 189323   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.237    |
# |    n_updates        | 34830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.7e+03  |
# |    ep_rew_mean      | 1.34e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 81       |
# |    time_elapsed     | 2371     |
# |    total_timesteps  | 192389   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.194    |
# |    n_updates        | 35597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.57e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 80       |
# |    time_elapsed     | 2497     |
# |    total_timesteps  | 200005   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.461    |
# |    n_updates        | 37501    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.46e+03 |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 79       |
# |    time_elapsed     | 2622     |
# |    total_timesteps  | 207867   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.277    |
# |    n_updates        | 39466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.36e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 78       |
# |    time_elapsed     | 2742     |
# |    total_timesteps  | 215176   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.174    |
# |    n_updates        | 41293    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.26e+03 |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 77       |
# |    time_elapsed     | 2854     |
# |    total_timesteps  | 221990   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.19     |
# |    n_updates        | 42997    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.18e+03 |
# |    ep_rew_mean      | 1.39e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 77       |
# |    time_elapsed     | 2968     |
# |    total_timesteps  | 229063   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.275    |
# |    n_updates        | 44765    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 76       |
# |    time_elapsed     | 3063     |
# |    total_timesteps  | 234865   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.192    |
# |    n_updates        | 46216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 75       |
# |    time_elapsed     | 3207     |
# |    total_timesteps  | 243676   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.188    |
# |    n_updates        | 48418    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.97e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 75       |
# |    time_elapsed     | 3298     |
# |    total_timesteps  | 249270   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.172    |
# |    n_updates        | 49817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.9e+03  |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 75       |
# |    time_elapsed     | 3401     |
# |    total_timesteps  | 255585   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.162    |
# |    n_updates        | 51396    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.83e+03 |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 74       |
# |    time_elapsed     | 3476     |
# |    total_timesteps  | 260141   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.248    |
# |    n_updates        | 52535    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.78e+03 |
# |    ep_rew_mean      | 1.35e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 74       |
# |    time_elapsed     | 3592     |
# |    total_timesteps  | 267348   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.175    |
# |    n_updates        | 54336    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.73e+03 |
# |    ep_rew_mean      | 1.35e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 74       |
# |    time_elapsed     | 3693     |
# |    total_timesteps  | 273446   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.242    |
# |    n_updates        | 55861    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 73       |
# |    time_elapsed     | 3803     |
# |    total_timesteps  | 280196   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.249    |
# |    n_updates        | 57548    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.89e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 73       |
# |    time_elapsed     | 3876     |
# |    total_timesteps  | 284775   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.26     |
# |    n_updates        | 58693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.89e+03 |
# |    ep_rew_mean      | 1.38e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 73       |
# |    time_elapsed     | 3966     |
# |    total_timesteps  | 290218   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.353    |
# |    n_updates        | 60054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.86e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 73       |
# |    time_elapsed     | 4023     |
# |    total_timesteps  | 293725   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.186    |
# |    n_updates        | 60931    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.8e+03  |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 72       |
# |    time_elapsed     | 4147     |
# |    total_timesteps  | 301417   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.96     |
# |    n_updates        | 62854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.83e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 72       |
# |    time_elapsed     | 4327     |
# |    total_timesteps  | 312454   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.287    |
# |    n_updates        | 65613    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.75e+03 |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 71       |
# |    time_elapsed     | 4425     |
# |    total_timesteps  | 318560   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0729   |
# |    n_updates        | 67139    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.69e+03 |
# |    ep_rew_mean      | 1.34e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 71       |
# |    time_elapsed     | 4511     |
# |    total_timesteps  | 323799   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.359    |
# |    n_updates        | 68449    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.68e+03 |
# |    ep_rew_mean      | 1.34e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 71       |
# |    time_elapsed     | 4591     |
# |    total_timesteps  | 328763   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.34     |
# |    n_updates        | 69690    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.64e+03 |
# |    ep_rew_mean      | 1.32e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 71       |
# |    time_elapsed     | 4679     |
# |    total_timesteps  | 334121   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.217    |
# |    n_updates        | 71030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.68e+03 |
# |    ep_rew_mean      | 1.33e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 70       |
# |    time_elapsed     | 4882     |
# |    total_timesteps  | 346640   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.535    |
# |    n_updates        | 74159    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.64e+03 |
# |    ep_rew_mean      | 1.31e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 70       |
# |    time_elapsed     | 4985     |
# |    total_timesteps  | 352954   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.537    |
# |    n_updates        | 75738    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.65e+03 |
# |    ep_rew_mean      | 1.32e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 70       |
# |    time_elapsed     | 5050     |
# |    total_timesteps  | 357060   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.324    |
# |    n_updates        | 76764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.61e+03 |
# |    ep_rew_mean      | 1.28e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 70       |
# |    time_elapsed     | 5122     |
# |    total_timesteps  | 361411   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.195    |
# |    n_updates        | 77852    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.61e+03 |
# |    ep_rew_mean      | 1.29e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 70       |
# |    time_elapsed     | 5247     |
# |    total_timesteps  | 369128   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.47     |
# |    n_updates        | 79781    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.62e+03 |
# |    ep_rew_mean      | 1.29e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 70       |
# |    time_elapsed     | 5382     |
# |    total_timesteps  | 377398   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.481    |
# |    n_updates        | 81849    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.64e+03 |
# |    ep_rew_mean      | 1.29e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 69       |
# |    time_elapsed     | 5531     |
# |    total_timesteps  | 386483   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.335    |
# |    n_updates        | 84120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.61e+03 |
# |    ep_rew_mean      | 1.26e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 69       |
# |    time_elapsed     | 5597     |
# |    total_timesteps  | 390479   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.13     |
# |    n_updates        | 85119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.61e+03 |
# |    ep_rew_mean      | 1.26e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 69       |
# |    time_elapsed     | 5677     |
# |    total_timesteps  | 395385   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.466    |
# |    n_updates        | 86346    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.58e+03 |
# |    ep_rew_mean      | 1.26e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 69       |
# |    time_elapsed     | 5771     |
# |    total_timesteps  | 401188   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.73     |
# |    n_updates        | 87796    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.59e+03 |
# |    ep_rew_mean      | 1.28e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 69       |
# |    time_elapsed     | 5883     |
# |    total_timesteps  | 408148   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.224    |
# |    n_updates        | 89536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.59e+03 |
# |    ep_rew_mean      | 1.28e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 69       |
# |    time_elapsed     | 5983     |
# |    total_timesteps  | 414134   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.134    |
# |    n_updates        | 91033    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.62e+03 |
# |    ep_rew_mean      | 1.29e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 69       |
# |    time_elapsed     | 6109     |
# |    total_timesteps  | 421804   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.488    |
# |    n_updates        | 92950    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.63e+03 |
# |    ep_rew_mean      | 1.3e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 68       |
# |    time_elapsed     | 6254     |
# |    total_timesteps  | 430719   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.341    |
# |    n_updates        | 95179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.66e+03 |
# |    ep_rew_mean      | 1.3e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 68       |
# |    time_elapsed     | 6392     |
# |    total_timesteps  | 439290   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.249    |
# |    n_updates        | 97322    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.63e+03 |
# |    ep_rew_mean      | 1.3e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 68       |
# |    time_elapsed     | 6463     |
# |    total_timesteps  | 443543   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.342    |
# |    n_updates        | 98385    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.65e+03 |
# |    ep_rew_mean      | 1.3e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 68       |
# |    time_elapsed     | 6566     |
# |    total_timesteps  | 449958   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.303    |
# |    n_updates        | 99989    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.66e+03 |
# |    ep_rew_mean      | 1.3e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 68       |
# |    time_elapsed     | 6670     |
# |    total_timesteps  | 456276   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.231    |
# |    n_updates        | 101568   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.71e+03 |
# |    ep_rew_mean      | 1.34e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 68       |
# |    time_elapsed     | 6808     |
# |    total_timesteps  | 464720   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.197    |
# |    n_updates        | 103679   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.72e+03 |
# |    ep_rew_mean      | 1.33e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 68       |
# |    time_elapsed     | 6954     |
# |    total_timesteps  | 473642   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.277    |
# |    n_updates        | 105910   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.7e+03  |
# |    ep_rew_mean      | 1.32e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 67       |
# |    time_elapsed     | 7096     |
# |    total_timesteps  | 482336   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0974   |
# |    n_updates        | 108083   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.71e+03 |
# |    ep_rew_mean      | 1.32e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 67       |
# |    time_elapsed     | 7209     |
# |    total_timesteps  | 489417   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.445    |
# |    n_updates        | 109854   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.72e+03 |
# |    ep_rew_mean      | 1.33e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 67       |
# |    time_elapsed     | 7308     |
# |    total_timesteps  | 495460   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.249    |
# |    n_updates        | 111364   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.76e+03 |
# |    ep_rew_mean      | 1.34e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 67       |
# |    time_elapsed     | 7453     |
# |    total_timesteps  | 504410   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.314    |
# |    n_updates        | 113602   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.79e+03 |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 67       |
# |    time_elapsed     | 7598     |
# |    total_timesteps  | 513279   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.303    |
# |    n_updates        | 115819   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.74e+03 |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 67       |
# |    time_elapsed     | 7717     |
# |    total_timesteps  | 520569   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.354    |
# |    n_updates        | 117642   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.76e+03 |
# |    ep_rew_mean      | 1.38e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 67       |
# |    time_elapsed     | 7847     |
# |    total_timesteps  | 528519   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.38     |
# |    n_updates        | 119629   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.76e+03 |
# |    ep_rew_mean      | 1.39e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 67       |
# |    time_elapsed     | 7917     |
# |    total_timesteps  | 532796   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.356    |
# |    n_updates        | 120698   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.83e+03 |
# |    ep_rew_mean      | 1.44e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 67       |
# |    time_elapsed     | 8102     |
# |    total_timesteps  | 544133   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.224    |
# |    n_updates        | 123533   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.79e+03 |
# |    ep_rew_mean      | 1.41e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 67       |
# |    time_elapsed     | 8174     |
# |    total_timesteps  | 548545   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.332    |
# |    n_updates        | 124636   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.8e+03  |
# |    ep_rew_mean      | 1.43e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 67       |
# |    time_elapsed     | 8321     |
# |    total_timesteps  | 557599   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0874   |
# |    n_updates        | 126899   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.75e+03 |
# |    ep_rew_mean      | 1.42e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 66       |
# |    time_elapsed     | 8392     |
# |    total_timesteps  | 561946   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.388    |
# |    n_updates        | 127986   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.78e+03 |
# |    ep_rew_mean      | 1.44e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 66       |
# |    time_elapsed     | 8500     |
# |    total_timesteps  | 568561   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.712    |
# |    n_updates        | 129640   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.78e+03 |
# |    ep_rew_mean      | 1.44e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 66       |
# |    time_elapsed     | 8572     |
# |    total_timesteps  | 573033   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.75     |
# |    n_updates        | 130758   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.81e+03 |
# |    ep_rew_mean      | 1.45e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 66       |
# |    time_elapsed     | 8720     |
# |    total_timesteps  | 582100   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.365    |
# |    n_updates        | 133024   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.81e+03 |
# |    ep_rew_mean      | 1.44e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 66       |
# |    time_elapsed     | 8830     |
# |    total_timesteps  | 588877   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.243    |
# |    n_updates        | 134719   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.79e+03 |
# |    ep_rew_mean      | 1.42e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 66       |
# |    time_elapsed     | 8899     |
# |    total_timesteps  | 593021   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.22     |
# |    n_updates        | 135755   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.75e+03 |
# |    ep_rew_mean      | 1.41e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 66       |
# |    time_elapsed     | 8958     |
# |    total_timesteps  | 596651   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.613    |
# |    n_updates        | 136662   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.73e+03 |
# |    ep_rew_mean      | 1.41e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 66       |
# |    time_elapsed     | 9072     |
# |    total_timesteps  | 603710   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.241    |
# |    n_updates        | 138427   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.71e+03 |
# |    ep_rew_mean      | 1.42e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 66       |
# |    time_elapsed     | 9172     |
# |    total_timesteps  | 609865   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.871    |
# |    n_updates        | 139966   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.72e+03 |
# |    ep_rew_mean      | 1.43e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 66       |
# |    time_elapsed     | 9261     |
# |    total_timesteps  | 615350   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.33     |
# |    n_updates        | 141337   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.74e+03 |
# |    ep_rew_mean      | 1.44e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 66       |
# |    time_elapsed     | 9407     |
# |    total_timesteps  | 624364   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.107    |
# |    n_updates        | 143590   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.73e+03 |
# |    ep_rew_mean      | 1.44e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 66       |
# |    time_elapsed     | 9484     |
# |    total_timesteps  | 629076   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.891    |
# |    n_updates        | 144768   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.68e+03 |
# |    ep_rew_mean      | 1.4e+03  |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 66       |
# |    time_elapsed     | 9548     |
# |    total_timesteps  | 633030   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.184    |
# |    n_updates        | 145757   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.63e+03 |
# |    ep_rew_mean      | 1.38e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 66       |
# |    time_elapsed     | 9601     |
# |    total_timesteps  | 636296   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.201    |
# |    n_updates        | 146573   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.57e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 66       |
# |    time_elapsed     | 9656     |
# |    total_timesteps  | 639693   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.535    |
# |    n_updates        | 147423   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.57e+03 |
# |    ep_rew_mean      | 1.38e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 66       |
# |    time_elapsed     | 9765     |
# |    total_timesteps  | 646385   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.185    |
# |    n_updates        | 149096   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.6e+03  |
# |    ep_rew_mean      | 1.38e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 66       |
# |    time_elapsed     | 9908     |
# |    total_timesteps  | 655145   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.537    |
# |    n_updates        | 151286   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.56e+03 |
# |    ep_rew_mean      | 1.37e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 66       |
# |    time_elapsed     | 9994     |
# |    total_timesteps  | 660330   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.331    |
# |    n_updates        | 152582   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.54e+03 |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 66       |
# |    time_elapsed     | 10100    |
# |    total_timesteps  | 666968   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.181    |
# |    n_updates        | 154241   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.53e+03 |
# |    ep_rew_mean      | 1.34e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 65       |
# |    time_elapsed     | 10206    |
# |    total_timesteps  | 673515   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.318    |
# |    n_updates        | 155878   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.54e+03 |
# |    ep_rew_mean      | 1.34e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 65       |
# |    time_elapsed     | 10351    |
# |    total_timesteps  | 682348   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.327    |
# |    n_updates        | 158086   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.56e+03 |
# |    ep_rew_mean      | 1.35e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 65       |
# |    time_elapsed     | 10459    |
# |    total_timesteps  | 688916   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.343    |
# |    n_updates        | 159728   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.49e+03 |
# |    ep_rew_mean      | 1.32e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 65       |
# |    time_elapsed     | 10524    |
# |    total_timesteps  | 692887   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.331    |
# |    n_updates        | 160721   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.51e+03 |
# |    ep_rew_mean      | 1.32e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 65       |
# |    time_elapsed     | 10633    |
# |    total_timesteps  | 699622   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.234    |
# |    n_updates        | 162405   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.51e+03 |
# |    ep_rew_mean      | 1.31e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 65       |
# |    time_elapsed     | 10785    |
# |    total_timesteps  | 708947   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.421    |
# |    n_updates        | 164736   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.53e+03 |
# |    ep_rew_mean      | 1.33e+03 |
# |    exploration_rate | 0.05     |
# ...
# |    time_elapsed     | 11760    |
# |    total_timesteps  | 768959   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.259    |
# |    n_updates        | 179739   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.64e+03 |
# |    ep_rew_mean      | 1.34e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 65       |
# |    time_elapsed     | 11930    |
# |    total_timesteps  | 779422   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.391    |
# |    n_updates        | 182355   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.64e+03 |
# |    ep_rew_mean      | 1.35e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 65       |
# |    time_elapsed     | 12076    |
# |    total_timesteps  | 788472   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.355    |
# |    n_updates        | 184617   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.68e+03 |
# |    ep_rew_mean      | 1.36e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 65       |
# |    time_elapsed     | 12219    |
# |    total_timesteps  | 797270   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.92     |
# |    n_updates        | 186817   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.7e+03  |
# |    ep_rew_mean      | 1.38e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 65       |
# |    time_elapsed     | 12316    |
# |    total_timesteps  | 803186   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.595    |
# |    n_updates        | 188296   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.72e+03 |
# |    ep_rew_mean      | 1.39e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 65       |
# |    time_elapsed     | 12403    |
# |    total_timesteps  | 808622   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.31     |
# |    n_updates        | 189655   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.75e+03 |
# |    ep_rew_mean      | 1.41e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 65       |
# |    time_elapsed     | 12501    |
# |    total_timesteps  | 814638   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.36     |
# |    n_updates        | 191159   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.76e+03 |
# |    ep_rew_mean      | 1.42e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 65       |
# |    time_elapsed     | 12626    |
# |    total_timesteps  | 822295   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.579    |
# |    n_updates        | 193073   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.74e+03 |
# |    ep_rew_mean      | 1.42e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 65       |
# |    time_elapsed     | 12729    |
# |    total_timesteps  | 828662   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.343    |
# |    n_updates        | 194665   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.75e+03 |
# |    ep_rew_mean      | 1.42e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 65       |
# |    time_elapsed     | 12838    |
# |    total_timesteps  | 835300   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.438    |
# |    n_updates        | 196324   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.75e+03 |
# |    ep_rew_mean      | 1.43e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 65       |
# |    time_elapsed     | 12942    |
# |    total_timesteps  | 841700   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.549    |
# |    n_updates        | 197924   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.79e+03 |
# |    ep_rew_mean      | 1.44e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 64       |
# |    time_elapsed     | 13116    |
# |    total_timesteps  | 852384   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.297    |
# |    n_updates        | 200595   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.77e+03 |
# |    ep_rew_mean      | 1.43e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 64       |
# |    time_elapsed     | 13225    |
# |    total_timesteps  | 859171   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.317    |
# |    n_updates        | 202292   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.76e+03 |
# |    ep_rew_mean      | 1.42e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 64       |
# |    time_elapsed     | 13319    |
# |    total_timesteps  | 864885   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.41     |
# |    n_updates        | 203721   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.8e+03  |
# |    ep_rew_mean      | 1.45e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 64       |
# |    time_elapsed     | 13451    |
# |    total_timesteps  | 872943   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.292    |
# |    n_updates        | 205735   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.78e+03 |
# |    ep_rew_mean      | 1.44e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 64       |
# |    time_elapsed     | 13529    |
# |    total_timesteps  | 877787   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.396    |
# |    n_updates        | 206946   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.81e+03 |
# |    ep_rew_mean      | 1.46e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 64       |
# |    time_elapsed     | 13733    |
# |    total_timesteps  | 890255   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.762    |
# |    n_updates        | 210063   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.84e+03 |
# |    ep_rew_mean      | 1.46e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 64       |
# |    time_elapsed     | 13880    |
# |    total_timesteps  | 899380   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.435    |
# |    n_updates        | 212344   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.85e+03 |
# |    ep_rew_mean      | 1.47e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 64       |
# |    time_elapsed     | 13979    |
# |    total_timesteps  | 905412   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.225    |
# |    n_updates        | 213852   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.87e+03 |
# |    ep_rew_mean      | 1.48e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 64       |
# |    time_elapsed     | 14098    |
# |    total_timesteps  | 912670   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.69     |
# |    n_updates        | 215667   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.85e+03 |
# |    ep_rew_mean      | 1.46e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 64       |
# |    time_elapsed     | 14221    |
# |    total_timesteps  | 920224   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.185    |
# |    n_updates        | 217555   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.84e+03 |
# |    ep_rew_mean      | 1.44e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 64       |
# |    time_elapsed     | 14374    |
# |    total_timesteps  | 929728   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.384    |
# |    n_updates        | 219931   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.88e+03 |
# |    ep_rew_mean      | 1.46e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 64       |
# |    time_elapsed     | 14542    |
# |    total_timesteps  | 939931   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.692    |
# |    n_updates        | 222482   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 1.47e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 64       |
# |    time_elapsed     | 14680    |
# |    total_timesteps  | 948420   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.169    |
# |    n_updates        | 224604   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 1.49e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 64       |
# |    time_elapsed     | 14794    |
# |    total_timesteps  | 955313   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.366    |
# |    n_updates        | 226328   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 1.49e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 64       |
# |    time_elapsed     | 14908    |
# |    total_timesteps  | 962306   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.438    |
# |    n_updates        | 228076   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.9e+03  |
# |    ep_rew_mean      | 1.47e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 64       |
# |    time_elapsed     | 15014    |
# |    total_timesteps  | 968964   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.27     |
# |    n_updates        | 229740   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.88e+03 |
# |    ep_rew_mean      | 1.47e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 64       |
# |    time_elapsed     | 15136    |
# |    total_timesteps  | 976389   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.51     |
# |    n_updates        | 231597   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.85e+03 |
# |    ep_rew_mean      | 1.47e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 64       |
# |    time_elapsed     | 15229    |
# |    total_timesteps  | 982045   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.387    |
# |    n_updates        | 233011   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.85e+03 |
# |    ep_rew_mean      | 1.46e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 64       |
# |    time_elapsed     | 15324    |
# |    total_timesteps  | 987955   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.12     |
# |    n_updates        | 234488   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.88e+03 |
# |    ep_rew_mean      | 1.47e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 64       |
# |    time_elapsed     | 15470    |
# |    total_timesteps  | 996927   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.378    |
# |    n_updates        | 236731   |
# ----------------------------------

# %%
import numpy as np
import tensorflow as tf

# %%
obs = env.reset()
start_time = time.time()
total_rewards = 0
game_scores = []
steps_per_episode = []
episode_rewards = []
while True:
    action, states = model.predict(obs.copy())
    action = action.item()  # convert NumPy array to scalar integer
    obs, rewards, done, info = env.step((action))
    total_rewards += rewards
    episode_rewards.append(rewards)
    if done:
        game_scores.append(info['score'])
        steps_per_episode.append(len(episode_rewards))
        episode_rewards = []
        obs = env.reset()
        if len(game_scores) == 10:
            break
test_time = time.time() - start_time

# %%
print(f'Average steps per episode for seed 10: {sum(steps_per_episode)/len(steps_per_episode)}')
print(f'Average mean reward for seed 10: {total_rewards/len(game_scores)}')
print(f'Average game score for seed 10: {sum(game_scores)/len(game_scores)}')
print(f'Training time for seed 10: {training_time:.2f} seconds')
print(f'Test time for seed 10: {test_time:.2f} seconds')
# Out:
# Average steps per episode for seed 10: 10106.1
# Average mean reward for seed 10: 966.7
# Average game score for seed 10: 600.0
# Training time for seed 10: 15521.58 seconds
# Test time for seed 10: 365.16 seconds

# %%
model = DQN.load('./train/best_model_50000/')
